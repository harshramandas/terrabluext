# %%
import pandas as pd
df = pd.read_csv('Test_Data.csv')
print(df)
# Out:
#       Unnamed: 0   A       B       C        D       E       F      G       H  \
# 0              0   6  860.62  809.73   919.69   30.87   69.81  65.24   74.10
# 1              1   7  871.58  789.74   929.69   32.82   68.94  64.54   75.97
# 2              2   6  854.87  789.74   929.69   32.38   70.29  64.54   75.97
# 3              3   7  823.73  759.75   879.71   29.19   72.93  68.20   78.97
# 4              4   6  823.44  759.75   879.71   28.98   72.96  68.20   78.97
# 5              5   6  825.02  749.75   889.70   37.81   72.88  67.44   80.03
# 6              6  10  763.63  579.81  1189.60  126.43   80.53  50.44  103.48
# 7              7  11  792.09  499.83  1499.50  217.95   80.65  40.01  120.04
# 8              8   9  752.25  529.82  1279.57  136.87   82.01  46.89  113.25
# 9              9   7  659.78  599.80   749.75   43.39   91.32  80.03  100.03
# 10            10   8  635.12  589.80   709.76   27.53   94.64  84.54  101.73
# ...

# %%
#Task 1

# %%
A = df[["A","B","C","G","R","X6","X8"]]
A
# Out:
#        A       B       C      G      R       X6      X8
# 0      6  860.62  809.73  65.24    573  88.1326  0.2113
# 1      7  871.58  789.74  64.54    849  84.8057  0.2151
# 2      6  854.87  789.74  64.54    687  90.5386  0.2127
# 3      7  823.73  759.75  68.20    475  86.1053  0.2081
# 4      6  823.44  759.75  68.20    424  87.0283  0.2429
# 5      6  825.02  749.75  67.44    646  76.9350  0.2139
# 6     10  763.63  579.81  50.44  10334  33.4140  0.1819
# 7     11  792.09  499.83  40.01  31298  69.5827  0.2971
# 8      9  752.25  529.82  46.89  15586  74.0408  0.1846
# 9      7  659.78  599.80  80.03   1031  74.6848  0.2467
# 10     8  635.12  589.80  84.54    454  63.4361  0.2099
# 11     9  641.38  599.80  86.99    441  57.8231  0.2126
# 12     8  653.65  589.80  80.03    544  72.6103  0.2434
# 13     8  673.03  589.80  80.03    512  72.8516  0.2073
# 14    11  679.54  619.79  80.03    416  84.8558  0.2102
# 15     9  685.25  609.80  75.97    683  74.5242  0.1737
# ...

# %%
import csv
reader = csv.DictReader(open('Test_Data.csv'))
AL = []
BL = []
CL = []
DL = []
EL = []
FL = []


A = {}
B = {}
C = {}
D = {}
E = {}
F = {}

for row in reader:
    A = {}
    B = {}
    C = {}
    D = {}
    E = {}
    F = {}
    if row['Class'] == 'A':
        A['A'] = row['A']
        A['B'] = row['B']
        A['C'] = row['C']
        A['G'] = row['G']
        A['R'] = row['R']
        A['X6'] = row['X6']
        A['X8'] = row['X8']
        AL.append(A)
    if row['Class'] == 'B':
        B['A'] = row['A']
        B['B'] = row['B']
        B['C'] = row['C']
        B['G'] = row['G']
        B['R'] = row['R']
        B['X6'] = row['X6']
        B['X8'] = row['X8']
        BL.append(B)
    if row['Class'] == 'C':
        C['A'] = row['A']
        C['B'] = row['B']
        C['C'] = row['C']
        C['G'] = row['G']
        C['R'] = row['R']
        C['X6'] = row['X6']
        C['X8'] = row['X8']
        CL.append(C)
    if row['Class'] == 'D':
        D['A'] = row['A']
        D['B'] = row['B']
        D['C'] = row['C']
        D['G'] = row['G']
        D['R'] = row['R']
        D['X6'] = row['X6']
        D['X8'] = row['X8']
        DL.append(D)
    if row['Class'] == 'E':
        E['A'] = row['A']
        E['B'] = row['B']
        E['C'] = row['C']
        E['G'] = row['G']
        E['R'] = row['R']
        E['X6'] = row['X6']
        E['X8'] = row['X8']
        EL.append(E)
    if row['Class'] == 'F':
        F['A'] = row['A']
        F['B'] = row['B']
        F['C'] = row['C']
        F['G'] = row['G']
        F['R'] = row['R']
        F['X6'] = row['X6']
        F['X8'] = row['X8']
        FL.append(F)
print(AL)
print(BL)
print(CL)
print(DL)
print(EL)
print(FL)
# Out:
# [{'A': '6', 'B': '860.62', 'C': '809.73', 'G': '65.24', 'R': '573', 'X6': '88.1326', 'X8': '0.2113'}, {'A': '7', 'B': '871.58', 'C': '789.74', 'G': '64.54', 'R': '849', 'X6': '84.8057', 'X8': '0.2151'}, {'A': '6', 'B': '854.87', 'C': '789.74', 'G': '64.54', 'R': '687', 'X6': '90.5386', 'X8': '0.2127'}, {'A': '7', 'B': '823.73', 'C': '759.75', 'G': '68.2', 'R': '475', 'X6': '86.1053', 'X8': '0.2081'}, {'A': '6', 'B': '823.44', 'C': '759.75', 'G': '68.2', 'R': '424', 'X6': '87.0283', 'X8': '0.2429'}, {'A': '6', 'B': '825.02', 'C': '749.75', 'G': '67.44', 'R': '646', 'X6': '76.935', 'X8': '0.2139'}, {'A': '10', 'B': '763.63', 'C': '579.81', 'G': '50.44', 'R': '10334', 'X6': '33.414', 'X8': '0.1819'}, {'A': '11', 'B': '792.09', 'C': '499.83', 'G': '40.01', 'R': '31298', 'X6': '69.5827', 'X8': '0.2971'}, {'A': '9', 'B': '752.25', 'C': '529.82', 'G': '46.89', 'R': '15586', 'X6': '74.0408', 'X8': '0.1846'}, {'A': '7', 'B': '659.78', 'C': '599.8', 'G': '80.03', 'R': '1031', 'X6': '74.6848', 
# ...

# %%
import csv

with open('A.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=AL[0].keys(),

                       )
    fc.writeheader()
    fc.writerows(AL)
with open('B.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=BL[0].keys(),

                       )
    fc.writeheader()
    fc.writerows(BL)
with open('C.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=CL[0].keys(),

                       )
    fc.writeheader()
    fc.writerows(CL)
with open('D.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=DL[0].keys(),

                       )
    fc.writeheader()
    fc.writerows(DL)
with open('E.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=EL[0].keys(),

                       )
    fc.writeheader()
    fc.writerows(EL)
with open('F.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=FL[0].keys(),

                       )
    fc.writeheader()
    fc.writerows(FL)

# %%
#Task2 and Task 3

# %%
dfa = pd.read_csv('A.csv')
dfb = pd.read_csv('B.csv')
dfc = pd.read_csv('C.csv')
dfd = pd.read_csv('D.csv')
dfe = pd.read_csv('E.csv')
dff = pd.read_csv('F.csv')

# %%
dfa.describe()
# Out:
#                  A            B            C            G             R  \
# count  1052.000000  1052.000000  1052.000000  1052.000000   1052.000000
# mean      8.576046   893.219534   750.871245    60.383498   3410.617871
# std       2.504595   174.609851   189.572779    13.400865   6081.740883
# min       4.000000   470.990000   309.900000    38.230000     14.000000
# 25%       7.000000   760.020000   609.800000    50.440000    847.500000
# 50%       8.000000   887.520000   749.750000    56.090000   1679.500000
# 75%       9.000000  1050.120000   909.700000    66.690000   3430.750000
# max      21.000000  1193.520000  1139.620000   120.040000  59046.000000
#
#                 X6           X8
# count  1052.000000  1052.000000
# mean     62.932346     0.237432
# std      22.531979     0.060484
# min       4.166700     0.094400
# 25%      45.211650     0.180600
# 50%      66.284900     0.246000
# 75%      82.593800     0.284650
# max     100.000000     0.362200

# %%
dfb.describe()
# Out:
#                  A            B            C            G             R  \
# count  1163.000000  1163.000000  1163.000000  1163.000000   1163.000000
# mean      8.208942   813.830284   693.646578    67.423637   2770.271711
# std       1.678103   188.226739   175.846559    19.819169   5970.600322
# min       4.000000   372.080000   309.900000    37.510000      5.000000
# 25%       7.000000   653.680000   569.810000    53.120000    575.500000
# 50%       8.000000   832.660000   699.770000    63.180000   1097.000000
# 75%       9.000000   966.230000   829.720000    74.100000   2424.000000
# max      19.000000  1163.360000  1109.630000   142.900000  78603.000000
#
#                 X6           X8
# count  1163.000000  1163.000000
# mean     56.159403     0.217026
# std      22.294839     0.063019
# min       5.853700     0.101800
# 25%      38.913050     0.173500
# 50%      57.542600     0.210700
# 75%      74.219000     0.278850
# max      98.755400     0.361100

# %%
dfc.describe()
# Out:
#                  A            B            C            G             R  \
# count  1694.000000  1694.000000  1694.000000  1694.000000   1694.000000
# mean      7.748524   927.232509   803.964469    58.968524   3290.348878
# std       2.061212   181.975550   173.545224    12.811666   6343.879438
# min       4.000000   480.840000   309.900000    37.510000     18.000000
# 25%       7.000000   794.310000   709.760000    47.260000    657.500000
# 50%       8.000000   911.825000   809.730000    57.710000   1400.000000
# 75%       8.000000  1103.930000   939.690000    67.440000   3648.750000
# max      27.000000  1267.760000  1139.620000   117.690000  99096.000000
#
#                 X6           X8
# count  1694.000000  1694.000000
# mean     69.925165     0.231050
# std      19.565174     0.047376
# min       8.000000     0.103100
# 25%      56.959300     0.210425
# 50%      74.084500     0.220700
# 75%      85.799675     0.255550
# max      99.263800     0.358600

# %%
dfd.describe()
# Out:
#                 A            B            C           G             R  \
# count  202.000000   202.000000   202.000000  202.000000    202.000000
# mean    16.143564   805.085693   680.367624   68.814851   2641.188119
# std      8.398897   202.255136   184.837640   18.718445   4422.918804
# min      5.000000   599.380000   359.880000   38.970000     26.000000
# 25%      8.000000   635.342500   589.800000   51.300000    129.250000
# 50%     16.500000   686.435000   619.790000   64.545000    687.000000
# 75%     25.000000   951.835000   787.240000   88.260000   3571.750000
# max     28.000000  1259.580000  1119.630000   95.270000  31678.000000
#
#                X6          X8
# count  202.000000  202.000000
# mean    51.769753    0.208135
# std     21.803495    0.065011
# min      8.366500    0.135400
# 25%     33.195700    0.142200
# 50%     50.730800    0.181250
# 75%     69.623000    0.251775
# max     95.240900    0.359100

# %%
dfe.describe()
# Out:
#                  A            B            C            G             R  \
# count  1029.000000  1029.000000  1029.000000  1029.000000   1029.000000
# mean     12.443149   848.512177   726.006589    64.434820   2776.046647
# std       6.617828   209.793019   204.820583    16.230826   5738.553575
# min       4.000000   498.820000   309.900000    38.230000      9.000000
# 25%       7.000000   661.820000   589.800000    51.740000    351.000000
# 50%       9.000000   796.680000   659.780000    57.710000    951.000000
# 75%      18.000000  1040.760000   919.690000    81.110000   3132.000000
# max      29.000000  1304.800000  1169.610000   113.250000  66261.000000
#
#                 X6           X8
# count  1029.000000  1029.000000
# mean     55.052573     0.216995
# std      22.269585     0.065712
# min       5.946300     0.113500
# 25%      37.211700     0.172600
# 50%      56.637200     0.210800
# 75%      72.848700     0.255300
# max      98.217900     0.361700

# %%
dff.describe()
# Out:
#                 A            B            C           G             R  \
# count  699.000000   699.000000   699.000000  699.000000    699.000000
# mean     9.726753   935.594592   784.030300   57.370200   3927.686695
# std      4.363631   183.032058   182.913254   13.420606   3934.845772
# min      5.000000   508.250000   319.890000   38.230000      4.000000
# 25%      7.000000   841.925000   679.770000   47.825000   2170.000000
# 50%      8.000000   906.150000   769.740000   56.090000   3424.000000
# 75%     10.000000  1127.380000   959.680000   60.630000   4808.000000
# max     28.000000  1271.000000  1139.620000  115.420000  71015.000000
#
#                X6          X8
# count  699.000000  699.000000
# mean    66.951735    0.228322
# std     21.679599    0.053639
# min      9.166700    0.136300
# 25%     51.185650    0.180750
# 50%     71.032000    0.242000
# 75%     85.157900    0.258700
# max     99.179600    0.360600

# %%
#Task 4

# %%
dependentVariables = df.iloc[:, -1].values

# %%
dependentVariables
# Out:
# array(['A', 'A', 'A', ..., 'A', 'A', 'A'], dtype=object)

# %%
independentVariables = df.iloc[:, :-1].values

# %%
independentVariables
# Out:
# array([[0.0000000e+00, 6.0000000e+00, 8.6062000e+02, ..., 9.5633300e-04,
#         9.1500000e-07, 1.1900000e-07],
#        [1.0000000e+00, 7.0000000e+00, 8.7158000e+02, ..., 8.8780900e-04,
#         7.8800000e-07, 1.2800000e-07],
#        [2.0000000e+00, 6.0000000e+00, 8.5487000e+02, ..., 8.7533000e-04,
#         7.6600000e-07, 1.1500000e-07],
#        ...,
#        [5.8360000e+03, 9.0000000e+00, 7.1651000e+02, ..., 9.6365858e-02,
#         9.2863790e-03, 2.6088660e-03],
#        [5.8370000e+03, 9.0000000e+00, 7.0002000e+02, ..., 9.7821141e-02,
#         9.5689760e-03, 2.6157320e-03],
#        [5.8380000e+03, 8.0000000e+00, 7.6919000e+02, ..., 1.7065645e-02,
#         2.9123600e-04, 2.7600000e-07]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(independentVariables, dependentVariables, test_size=0.1,
                                                    random_state=0)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
rfe = RFE(model, 3)
rfe = rfe.fit(X_train, y_train)

# %%
print(rfe.ranking_)
print(rfe.support_)
17,26,27,35,37
# Out:
# [34 11 31 33 30 24 18 23 22 15 14 19 26 27 25  4  1 32 36 35 12 21 28 29
#  20  1  1  3  7 37  9 10 16  6  1 13  1 38  8  5  2 17]
# [False False False False False False False False False False False False
#  False False False False  True False False False False False False False
#  False  True  True False False False False False False False  True False
#   True False False False False False]

# %%
independentVariables = df.iloc[:, [17,26,27,35,37]].values

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=400, random_state=0)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
print("Accuracy Score:- ", accuracy_score(y_test, y_pred) * 100)
# Out:
# Accuracy Score:-  92.46575342465754

# %%
classifier = LogisticRegression()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# %%
print("Accuracy Score:- ", accuracy_score(y_test, y_pred) * 100)
# Out:
# Accuracy Score:-  51.54109589041096

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3)#gave maximum accuracy at n = 3
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# %%
print("Accuracy Score:- ", accuracy_score(y_test, y_pred) * 100)
# Out:
# Accuracy Score:-  72.77397260273972

# %%
from sklearn import svm
from sklearn.multiclass import OneVsRestClassifier
classifier = OneVsRestClassifier(svm.SVC(kernel='linear', probability=True,
                                 random_state=0))

# %%
print("Accuracy Score:- ", accuracy_score(y_test, y_pred) * 100)
# Out:
# Accuracy Score:-  92.46575342465754

# %%
# SVM and Random Forest giving best accuracy.

# %%
from sklearn.metrics import roc_curve, auc
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(6):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-6a126861b31b> in <module>()
#       5 roc_auc = dict()
#       6 for i in range(6):
# ----> 7     fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
#       8     roc_auc[i] = auc(fpr[i], tpr[i])
#       9
#
# IndexError: too many indices for array
